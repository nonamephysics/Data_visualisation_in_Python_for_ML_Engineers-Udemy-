# %%
import numpy as np 
from matplotlib import pyplot as plt

# %%
x = np.linspace(-4, 4, 1024)
y = .25 * (x + 4.) * (x + 1.) * (x - 2.)

# %%
plt.title ( 'Graph Title')
plt.xlabel ('X axis')
plt.ylabel ('Y axis')
plt.plot (x, y, c = 'k')

plt.show()
